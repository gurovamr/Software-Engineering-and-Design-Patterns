# %%
import Data_Loader
from pathlib import Path

# %%
path = Path("../data/")
loader = Data_Loader.DataLoader(path)
data = loader.load()

# %%
data.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0        1.0  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1        2.0       sepang    Sepang International Circuit  Kuala Lumpur
# 2        3.0      bahrain   Bahrain International Circuit        Sakhir
# 3        4.0    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4        5.0     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng    alt  \
# 0  Australia -37.84970  144.96800   10.0
# 1   Malaysia   2.76083  101.73800   18.0
# 2    Bahrain  26.03250   50.51060    7.0
# 3      Spain  41.57000    2.26111  109.0
# 4     Turkey  40.95170   29.40500  130.0
#
#                                                  url  constructorId  ...  \
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...            NaN  ...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...            NaN  ...
# ...
